# %% [markdown]
# <a href="https://colab.research.google.com/github/imshiv-10/Numerical-libraries/blob/main/matplotLib_Numerical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples);

# %%
plt.figure(figsize=(10,6))
years = np.arange(2000, 2006,1)
years.shape, len(yield_apples)
plt.plot(years, yield_apples )
plt.title('Yield of apples')
plt.xlabel('Year')
plt.ylabel('Yield')
# Out:
# Text(0, 0.5, 'Yield')

# %%
years = range(2000, 2012, 1)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.figure(figsize=(10,6))
plt.plot(years, apples,marker = 'x' , color = 'red', linestyle='--', linewidth='2', ms='10', mec='green', mew ='3', mfc='yellow', alpha =1.6)
plt.plot(years, oranges, marker = 'o', mew = '6', alpha=.6)
plt.xlabel('year')
plt.ylabel('Yield per/hct')
plt.title('Yield');

# %%
plt.figure(figsize=(10,6))
plt.plot(years, apples, 'x--g')
plt.plot(years, oranges, marker = 'o', mew = '6', alpha=.6)
plt.xlabel('year')
plt.ylabel('Yield per/hct')
plt.title('Yield');

# %%
plt.figure(figsize=(10,6))
plt.plot(years, oranges, 'or')
plt.title('Yield');

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
plt.rcParams['figure.figsize'] = (9,5)
plt.rcParams['font.size'] = 14
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(9,5))
plt.plot(years, apples, 's-b')
plt.plot(years, oranges, marker='o', linestyle= '--', mec='red', mfc='red', mew='2', color = 'red')
plt.xlabel('Year')
plt.ylabel('Yeild per hect')
plt.title('Crop Yield')
plt.legend(['apples', 'oranges']);

# %% [markdown]
# ## ScatterPlot

# %%
flowers_df = sns.load_dataset('iris')
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(flowers_df.species)
# Out:
# pandas.core.series.Series

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ###*Flower Sepal_width vs Sepal_length*

# %%
flowers_df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Dimensions');

# %%
plt.scatter(flowers_df.sepal_length, flowers_df.sepal_width)
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Sepal Dimensions');

# %%
plt.figure(figsize=(10,6))
plt.title('Sepal Dimensions')
sns.scatterplot(x =flowers_df.sepal_length,y= flowers_df.sepal_width, hue = flowers_df.species , s =200);

# %%
plt.figure(figsize=(10,6))
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', y = 'sepal_width', data=flowers_df, hue='species', s=100);

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.hist('sepal_width',data=flowers_df ,bins=5)
# Out:
# (array([11., 46., 68., 21.,  4.]),
#  array([2.  , 2.48, 2.96, 3.44, 3.92, 4.4 ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist('sepal_width',data=flowers_df ,bins=np.arange(2,5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.,  1.,  0.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#         4.75]),
#  <a list of 11 Patch objects>)

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
setosa_df.species.unique()
# Out:
# array(['setosa'], dtype=object)

# %%
plt.hist('sepal_length', data=setosa_df, color='b' ,bins=np.arange(4, 8, 0.25))
plt.hist('sepal_length', data=versicolor_df, color='g',bins=np.arange(4, 8, 0.25))
plt.hist('sepal_length', data=virginica_df, color='r',bins=np.arange(4, 8, 0.25))
# Out:
# (array([ 0.,  0.,  0.,  1.,  0.,  0.,  2.,  4.,  6., 11.,  9.,  5.,  4.,
#          2.,  5.]),
#  array([4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25, 6.5 ,
#         6.75, 7.  , 7.25, 7.5 , 7.75]),
#  <a list of 15 Patch objects>)

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width, alpha=0.4, bins=np.arange(2, 5, 0.25));

# %%
plt.title('Sepal Dimensions')
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width,virginica_df.sepal_width], stacked=True, bins=np.arange(2,5,0.25))
plt.legend(['setosa', 'versicolor', 'virginica'])

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples)
plt.legend(['apples', 'oranges'])

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.total_bill.shape, tips_df.tip.shape
# Out:
# ((244,), (244,))

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(flights_df)

# %%
sns.barplot(x='day', y='total_bill', data =tips_df)

# %%
plt.title('Billing per day via sex')
sns.barplot(y='day', x='total_bill', data=tips_df, hue='sex')

# %%
tips_pivot_df = tips_df.pivot("day","total_bill","tip")
tips_pivot_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-31177549cbae> in <module>
# ----> 1 tips_pivot_df = tips_df.pivot("day","total_bill","tip")
#       2 tips_pivot_df
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
# ...

# %%
flights_df1 = sns.load_dataset("flights")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(20,10))
sns.heatmap(flights_df, fmt = "d" ,annot=True, cmap='Blues')

# %%
from urllib.request import urlretrieve
urlretrieve('https://i.imgur.com/SkPbq.jpg', 'chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x7f82c23ac5b0>)

# %%
from PIL import Image
img = Image.open('chart.jpg')
img_array = np.array(img)
img_array.shape
# Out:
# (481, 640, 3)

# %%
plt.figure(figsize=(10,6))
plt.imshow(img)
plt.grid(True)
plt.title('Data Science meme')
plt.axis('on')
# Out:
# (-0.5, 639.5, 480.5, -0.5)

# %%
plt.grid(True)
plt.axis('on')
plt.imshow(img_array[100:200, 105:200])
img_array[100:200, 105:200]
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [254, 254, 254],
#         [255, 255, 255]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [255, 255, 255],
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))

# Use the axes for plotting
axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges']);
axes[0,0].set_title('Crop Yields in Kanto')


# Pass the axes into seaborn
axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, 
                s=100, 
                ax=axes[0,1]);

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Pass the axes into seaborn
axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2);
